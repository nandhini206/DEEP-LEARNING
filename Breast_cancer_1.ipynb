# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder

# %%
data='/content/Breast_cancer_data.csv'
df=pd.read_csv(data);
df.head()
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    diagnosis
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
df.isnull().sum()
# Out:
# mean_radius        0
# mean_texture       0
# mean_perimeter     0
# mean_area          0
# mean_smoothness    0
# diagnosis          0
# dtype: int64

# %%
X=df.iloc[:, :5]
y=df.iloc[:, 5:]

# %%
X
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# [569 rows x 5 columns]

# %%
y
# Out:
#      diagnosis
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 564          0
# 565          0
# 566          0
# 567          0
# 568          1
#
# [569 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from keras.layers import Dense
from keras.models import Sequential

# %%
model =Sequential()

model.add(Dense(64,input_dim=X_train.shape[1],activation='relu'))

model.add(Dense(32,activation='relu'))

model.add(Dense(units=1,activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                384
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2497 (9.75 KB)
# Trainable params: 2497 (9.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size=32, epochs=100,verbose=2)
# Out:
# Epoch 1/100
# 13/13 - 3s - loss: 0.6526 - accuracy: 0.6960 - 3s/epoch - 232ms/step
# Epoch 2/100
# 13/13 - 0s - loss: 0.5075 - accuracy: 0.9196 - 61ms/epoch - 5ms/step
# Epoch 3/100
# 13/13 - 0s - loss: 0.4002 - accuracy: 0.9296 - 53ms/epoch - 4ms/step
# Epoch 4/100
# 13/13 - 0s - loss: 0.3099 - accuracy: 0.9372 - 61ms/epoch - 5ms/step
# Epoch 5/100
# 13/13 - 0s - loss: 0.2459 - accuracy: 0.9372 - 55ms/epoch - 4ms/step
# Epoch 6/100
# 13/13 - 0s - loss: 0.2054 - accuracy: 0.9347 - 61ms/epoch - 5ms/step
# Epoch 7/100
# 13/13 - 0s - loss: 0.1829 - accuracy: 0.9447 - 70ms/epoch - 5ms/step
# Epoch 8/100
# 13/13 - 0s - loss: 0.1707 - accuracy: 0.9422 - 69ms/epoch - 5ms/step
# Epoch 9/100
# 13/13 - 0s - loss: 0.1625 - accuracy: 0.9422 - 58ms/epoch - 4ms/step
# Epoch 10/100
# 13/13 - 0s - loss: 0.1580 - accuracy: 0.9422 - 53ms/epoch - 4ms/step
# Epoch 11/100
# 13/13 - 0s - loss: 0.1549 - accuracy: 0.9472 - 52ms/epoch - 4ms/step
# Epoch 12/100
# 13/13 - 0s - loss: 0.1523 - accuracy: 0.9497 - 58ms/epoch - 4ms/step
# Epoch 13/100
# 13/13 - 0s - loss: 0.1509 - accuracy: 0.9472 - 59ms/epoch - 5ms/step
# Epoch 14/100
# 13/13 - 0s - loss: 0.1498 - accuracy: 0.9548 - 59ms/epoch - 5ms/step
# Epoch 15/100
# 13/13 - 0s - loss: 0.1483 - accuracy: 0.9548 - 60ms/epoch - 5ms/step
# Epoch 16/100
# 13/13 - 0s - loss: 0.1465 - accuracy: 0.9523 - 73ms/epoch - 6ms/step
# Epoch 17/100
# 13/13 - 0s - loss: 0.1463 - accuracy: 0.9472 - 69ms/epoch - 5ms/step
# Epoch 18/100
# 13/13 - 0s - loss: 0.1446 - accuracy: 0.9523 - 60ms/epoch - 5ms/step
# Epoch 19/100
# 13/13 - 0s - loss: 0.1440 - accuracy: 0.9523 - 63ms/epoch - 5ms/step
# Epoch 20/100
# 13/13 - 0s - loss: 0.1434 - accuracy: 0.9523 - 50ms/epoch - 4ms/step
# Epoch 21/100
# 13/13 - 0s - loss: 0.1430 - accuracy: 0.9523 - 47ms/epoch - 4ms/step
# Epoch 22/100
# 13/13 - 0s - loss: 0.1426 - accuracy: 0.9523 - 41ms/epoch - 3ms/step
# Epoch 23/100
# 13/13 - 0s - loss: 0.1414 - accuracy: 0.9523 - 39ms/epoch - 3ms/step
# Epoch 24/100
# 13/13 - 0s - loss: 0.1408 - accuracy: 0.9497 - 40ms/epoch - 3ms/step
# Epoch 25/100
# 13/13 - 0s - loss: 0.1406 - accuracy: 0.9497 - 44ms/epoch - 3ms/step
# Epoch 26/100
# 13/13 - 0s - loss: 0.1397 - accuracy: 0.9548 - 37ms/epoch - 3ms/step
# Epoch 27/100
# 13/13 - 0s - loss: 0.1403 - accuracy: 0.9472 - 39ms/epoch - 3ms/step
# Epoch 28/100
# 13/13 - 0s - loss: 0.1394 - accuracy: 0.9497 - 41ms/epoch - 3ms/step
# Epoch 29/100
# 13/13 - 0s - loss: 0.1391 - accuracy: 0.9523 - 39ms/epoch - 3ms/step
# Epoch 30/100
# 13/13 - 0s - loss: 0.1386 - accuracy: 0.9523 - 40ms/epoch - 3ms/step
# Epoch 31/100
# 13/13 - 0s - loss: 0.1381 - accuracy: 0.9523 - 39ms/epoch - 3ms/step
# Epoch 32/100
# 13/13 - 0s - loss: 0.1376 - accuracy: 0.9523 - 39ms/epoch - 3ms/step
# Epoch 33/100
# 13/13 - 0s - loss: 0.1382 - accuracy: 0.9497 - 38ms/epoch - 3ms/step
# Epoch 34/100
# 13/13 - 0s - loss: 0.1373 - accuracy: 0.9523 - 39ms/epoch - 3ms/step
# Epoch 35/100
# 13/13 - 0s - loss: 0.1370 - accuracy: 0.9472 - 41ms/epoch - 3ms/step
# Epoch 36/100
# 13/13 - 0s - loss: 0.1361 - accuracy: 0.9523 - 42ms/epoch - 3ms/step
# Epoch 37/100
# 13/13 - 0s - loss: 0.1370 - accuracy: 0.9472 - 42ms/epoch - 3ms/step
# Epoch 38/100
# 13/13 - 0s - loss: 0.1366 - accuracy: 0.9497 - 37ms/epoch - 3ms/step
# Epoch 39/100
# 13/13 - 0s - loss: 0.1361 - accuracy: 0.9497 - 38ms/epoch - 3ms/step
# Epoch 40/100
# 13/13 - 0s - loss: 0.1353 - accuracy: 0.9497 - 37ms/epoch - 3ms/step
# Epoch 41/100
# 13/13 - 0s - loss: 0.1354 - accuracy: 0.9497 - 41ms/epoch - 3ms/step
# Epoch 42/100
# 13/13 - 0s - loss: 0.1348 - accuracy: 0.9497 - 46ms/epoch - 4ms/step
# Epoch 43/100
# 13/13 - 0s - loss: 0.1348 - accuracy: 0.9497 - 46ms/epoch - 4ms/step
# Epoch 44/100
# 13/13 - 0s - loss: 0.1339 - accuracy: 0.9523 - 39ms/epoch - 3ms/step
# Epoch 45/100
# 13/13 - 0s - loss: 0.1357 - accuracy: 0.9523 - 39ms/epoch - 3ms/step
# Epoch 46/100
# 13/13 - 0s - loss: 0.1334 - accuracy: 0.9497 - 40ms/epoch - 3ms/step
# Epoch 47/100
# 13/13 - 0s - loss: 0.1343 - accuracy: 0.9472 - 39ms/epoch - 3ms/step
# Epoch 48/100
# 13/13 - 0s - loss: 0.1332 - accuracy: 0.9497 - 38ms/epoch - 3ms/step
# Epoch 49/100
# 13/13 - 0s - loss: 0.1326 - accuracy: 0.9523 - 38ms/epoch - 3ms/step
# Epoch 50/100
# 13/13 - 0s - loss: 0.1334 - accuracy: 0.9497 - 38ms/epoch - 3ms/step
# Epoch 51/100
# 13/13 - 0s - loss: 0.1333 - accuracy: 0.9548 - 45ms/epoch - 3ms/step
# Epoch 52/100
# 13/13 - 0s - loss: 0.1328 - accuracy: 0.9548 - 43ms/epoch - 3ms/step
# Epoch 53/100
# 13/13 - 0s - loss: 0.1323 - accuracy: 0.9523 - 39ms/epoch - 3ms/step
# Epoch 54/100
# 13/13 - 0s - loss: 0.1315 - accuracy: 0.9472 - 39ms/epoch - 3ms/step
# Epoch 55/100
# 13/13 - 0s - loss: 0.1319 - accuracy: 0.9472 - 42ms/epoch - 3ms/step
# Epoch 56/100
# 13/13 - 0s - loss: 0.1336 - accuracy: 0.9472 - 42ms/epoch - 3ms/step
# Epoch 57/100
# 13/13 - 0s - loss: 0.1310 - accuracy: 0.9523 - 41ms/epoch - 3ms/step
# Epoch 58/100
# 13/13 - 0s - loss: 0.1310 - accuracy: 0.9523 - 37ms/epoch - 3ms/step
# Epoch 59/100
# 13/13 - 0s - loss: 0.1309 - accuracy: 0.9472 - 38ms/epoch - 3ms/step
# Epoch 60/100
# 13/13 - 0s - loss: 0.1310 - accuracy: 0.9497 - 38ms/epoch - 3ms/step
# Epoch 61/100
# 13/13 - 0s - loss: 0.1301 - accuracy: 0.9497 - 37ms/epoch - 3ms/step
# Epoch 62/100
# 13/13 - 0s - loss: 0.1305 - accuracy: 0.9497 - 37ms/epoch - 3ms/step
# Epoch 63/100
# 13/13 - 0s - loss: 0.1303 - accuracy: 0.9497 - 37ms/epoch - 3ms/step
# Epoch 64/100
# 13/13 - 0s - loss: 0.1298 - accuracy: 0.9523 - 37ms/epoch - 3ms/step
# Epoch 65/100
# 13/13 - 0s - loss: 0.1290 - accuracy: 0.9548 - 38ms/epoch - 3ms/step
# Epoch 66/100
# 13/13 - 0s - loss: 0.1294 - accuracy: 0.9523 - 50ms/epoch - 4ms/step
# Epoch 67/100
# 13/13 - 0s - loss: 0.1292 - accuracy: 0.9497 - 39ms/epoch - 3ms/step
# Epoch 68/100
# 13/13 - 0s - loss: 0.1291 - accuracy: 0.9548 - 39ms/epoch - 3ms/step
# Epoch 69/100
# 13/13 - 0s - loss: 0.1306 - accuracy: 0.9497 - 40ms/epoch - 3ms/step
# Epoch 70/100
# 13/13 - 0s - loss: 0.1284 - accuracy: 0.9523 - 38ms/epoch - 3ms/step
# Epoch 71/100
# 13/13 - 0s - loss: 0.1281 - accuracy: 0.9523 - 35ms/epoch - 3ms/step
# Epoch 72/100
# 13/13 - 0s - loss: 0.1296 - accuracy: 0.9472 - 36ms/epoch - 3ms/step
# Epoch 73/100
# 13/13 - 0s - loss: 0.1273 - accuracy: 0.9523 - 36ms/epoch - 3ms/step
# Epoch 74/100
# 13/13 - 0s - loss: 0.1280 - accuracy: 0.9573 - 37ms/epoch - 3ms/step
# Epoch 75/100
# 13/13 - 0s - loss: 0.1275 - accuracy: 0.9548 - 38ms/epoch - 3ms/step
# Epoch 76/100
# 13/13 - 0s - loss: 0.1276 - accuracy: 0.9548 - 38ms/epoch - 3ms/step
# Epoch 77/100
# 13/13 - 0s - loss: 0.1272 - accuracy: 0.9573 - 39ms/epoch - 3ms/step
# Epoch 78/100
# 13/13 - 0s - loss: 0.1265 - accuracy: 0.9548 - 41ms/epoch - 3ms/step
# Epoch 79/100
# 13/13 - 0s - loss: 0.1266 - accuracy: 0.9523 - 39ms/epoch - 3ms/step
# Epoch 80/100
# 13/13 - 0s - loss: 0.1258 - accuracy: 0.9548 - 38ms/epoch - 3ms/step
# Epoch 81/100
# 13/13 - 0s - loss: 0.1267 - accuracy: 0.9523 - 38ms/epoch - 3ms/step
# Epoch 82/100
# 13/13 - 0s - loss: 0.1258 - accuracy: 0.9573 - 37ms/epoch - 3ms/step
# Epoch 83/100
# 13/13 - 0s - loss: 0.1266 - accuracy: 0.9523 - 40ms/epoch - 3ms/step
# Epoch 84/100
# 13/13 - 0s - loss: 0.1257 - accuracy: 0.9523 - 37ms/epoch - 3ms/step
# Epoch 85/100
# 13/13 - 0s - loss: 0.1253 - accuracy: 0.9523 - 38ms/epoch - 3ms/step
# Epoch 86/100
# 13/13 - 0s - loss: 0.1252 - accuracy: 0.9548 - 36ms/epoch - 3ms/step
# Epoch 87/100
# 13/13 - 0s - loss: 0.1251 - accuracy: 0.9573 - 36ms/epoch - 3ms/step
# Epoch 88/100
# 13/13 - 0s - loss: 0.1244 - accuracy: 0.9548 - 44ms/epoch - 3ms/step
# Epoch 89/100
# 13/13 - 0s - loss: 0.1248 - accuracy: 0.9497 - 40ms/epoch - 3ms/step
# Epoch 90/100
# 13/13 - 0s - loss: 0.1260 - accuracy: 0.9573 - 50ms/epoch - 4ms/step
# Epoch 91/100
# 13/13 - 0s - loss: 0.1242 - accuracy: 0.9573 - 37ms/epoch - 3ms/step
# Epoch 92/100
# 13/13 - 0s - loss: 0.1237 - accuracy: 0.9523 - 36ms/epoch - 3ms/step
# Epoch 93/100
# 13/13 - 0s - loss: 0.1230 - accuracy: 0.9523 - 38ms/epoch - 3ms/step
# Epoch 94/100
# 13/13 - 0s - loss: 0.1238 - accuracy: 0.9548 - 36ms/epoch - 3ms/step
# Epoch 95/100
# 13/13 - 0s - loss: 0.1242 - accuracy: 0.9573 - 39ms/epoch - 3ms/step
# Epoch 96/100
# 13/13 - 0s - loss: 0.1220 - accuracy: 0.9523 - 36ms/epoch - 3ms/step
# Epoch 97/100
# 13/13 - 0s - loss: 0.1227 - accuracy: 0.9548 - 37ms/epoch - 3ms/step
# Epoch 98/100
# 13/13 - 0s - loss: 0.1230 - accuracy: 0.9523 - 39ms/epoch - 3ms/step
# Epoch 99/100
# 13/13 - 0s - loss: 0.1230 - accuracy: 0.9497 - 36ms/epoch - 3ms/step
# Epoch 100/100
# 13/13 - 0s - loss: 0.1214 - accuracy: 0.9548 - 40ms/epoch - 3ms/step

# %%
loss, accuracy = model.evaluate(X_test, y_test)
loss, accuracy
# Out:
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1964 - accuracy: 0.9181
# (0.19642917811870575, 0.9181286692619324)

# %%
new_data_point = np.array([[17.99,10.38,122.8,1001,0.1184]])

new_data_point_scaled = scaler.transform(new_data_point)

prediction = model.predict(new_data_point_scaled)

predicted_class = (prediction > 0.5)

if predicted_class[0][0] == 1:
  print('Cancer')
else:
  print('No Cancer')
# Out:
# 1/1 [==============================] - 0s 70ms/step
# No Cancer
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
